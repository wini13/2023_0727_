# %%
import matplotlib.pyplot as plt
plt.figure()

# %%
#標準寫法
import matplotlib.pyplot as plt

# 1.製作figure(畫布)
fig = plt.figure()

# 2.在1.的figure上製作一個axes
ax_1 = fig.add_subplot(1, 1, 1)

# 3.將圖的數據儲存在axes中
X = [0, 1, 2]
Y = [3, 4, 5]
ax_1.plot(X, Y)

# 4.顯示圖
plt.show()

# %%
fig=plt.figure()
axes1=fig.add_subplot(1,3,1)
axes1.set_title('plot1')
axes2=fig.add_subplot(1,3,2)
axes2.set_title('plot2')
axes3=fig.add_subplot(1,3,3)
axes3.set_title('plot3')
plt.show()

# %%
import matplotlib.pyplot as plt
data=[1.4,5,7,8,9.2,11]
figure=plt.figure(figsize=(8,5))
axes=figure.add_subplot()
axes.plot(data,'r*')
plt.show()

# %%
student1={'chinese':76,'math':35,'english':87,'history':63}
student1.keys()
student1.values()

figure=plt.figure(figsize=(8,5),dpi=250,facecolor='#cccccc')
axes1=figure.add_subplot()
axes1.plot(student1.keys(),student1.values(),'r--*',label='shownu')

student2={'chinese':90,'math':56,'english':45,'history':50}

axes1.plot(student2.keys(),student2.values(),'b:*',label='hyungwon')
axes1.legend()
plt.show()

# %%
#使用codespace 要安裝中文字型
#install 要加-y
#命令列:sudo apt-get update -y
#命令列:sudo apt-get install -y fonts-wqy-zenhei
#說明網址:https://askubuntu.com/questions/490829/how-can-i-install-chinese-fonts-on-kubuntu-14-04
#字型位置:/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc

#import matplotlib.pyplot as plt
#from matplotlib.font_manager import FontProperties
#mac font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#mac font1=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=12)
#window font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)
#font=FontProperties(fname=r'/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=8)
#font1=FontProperties(fname=r'/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=12)

student1={'國文':78,'英文':87,'數學':75,'歷史':64,'公民':90}
figure=plt.figure(figsize=(8,5),dpi=300,facecolor='#dddddd')
axes1=figure.add_subplot()
axes1.plot(student1.keys(),student1.values(),'r*',label='yejun')
axes1.legend()
axes1.set_xticklabels(student1.keys(),fontproperties=font)
plt.show()
# Out:
# /tmp/ipykernel_27431/2189286779.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes1.set_xticklabels(student1.keys(),fontproperties=font)
