# %%
import random
def getScore():
    score=[]
    for i in range(5):
        score.append(random.randint(50,100))
    return score

def get_name(number):
    with open("names.txt",encoding="utf-8",newline='') as file:
        names_str=file.read()
        names_list=names_str.split(sep="\n")
        name=random.choices(names_list,k=number)
    return name

number = int(input("請輸入學生數:"))
name = get_name(number)
student=[]
for i in range(number):
    score=getScore()
    newlist=[name[i]]+score
    student.append(newlist)
student
# Out:
# [['龐皓芳', 55, 80, 81, 84, 84],
#  ['蔡欣汝', 76, 57, 91, 74, 73],
#  ['李政白', 70, 78, 59, 60, 50],
#  ['錢欣潔', 67, 72, 95, 98, 80],
#  ['戚亨', 69, 88, 89, 85, 51],
#  ['林希啟', 67, 54, 60, 67, 100],
#  ['盧冠發', 59, 62, 51, 85, 74],
#  ['許淑婷', 68, 84, 99, 52, 61],
#  ['張慧君', 73, 97, 100, 74, 85],
#  ['游倫城', 72, 70, 57, 56, 68],
#  ['李慈啟', 70, 55, 78, 57, 91],
#  ['王怡君', 82, 94, 56, 83, 96],
#  ['黃婷婷', 71, 51, 88, 76, 89],
#  ['杜明延', 70, 80, 63, 53, 89],
#  ['唐雪豪', 68, 95, 59, 88, 70],
#  ['孫火清', 66, 77, 68, 74, 62],
#  ['陳逸凡', 99, 81, 65, 72, 98],
#  ['張雅芬', 74, 52, 87, 72, 92],
#  ['張伊映', 83, 95, 96, 87, 80],
#  ['陳倩潔', 91, 100, 84, 65, 62],
#  ['黃佩芬', 78, 74, 50, 90, 92],
#  ['林志成', 86, 62, 77, 69, 65],
#  ['簡美君', 51, 85, 52, 71, 56],
#  ['陳嘉淑', 67, 59, 63, 50, 62],
#  ['王士銘', 60, 80, 70, 81, 100],
#  ['吳柏誠', 65, 64, 60, 51, 61],
#  ['黃必琪', 71, 90, 63, 67, 54],
#  ['楊易政', 63, 57, 56, 76, 88],
#  ['林康亮', 96, 65, 84, 100, 84],
#  ['陳得映', 84, 62, 72, 68, 63]]

# %%
import pandas as pd
students=pd.DataFrame(student,columns=['姓名','國文','英文','數學','歷史','生物'],index=range(1,number+1))
students
# Out:
#      姓名  國文   英文   數學   歷史   生物
# 1   龐皓芳  55   80   81   84   84
# 2   蔡欣汝  76   57   91   74   73
# 3   李政白  70   78   59   60   50
# 4   錢欣潔  67   72   95   98   80
# 5    戚亨  69   88   89   85   51
# 6   林希啟  67   54   60   67  100
# 7   盧冠發  59   62   51   85   74
# 8   許淑婷  68   84   99   52   61
# 9   張慧君  73   97  100   74   85
# 10  游倫城  72   70   57   56   68
# 11  李慈啟  70   55   78   57   91
# 12  王怡君  82   94   56   83   96
# 13  黃婷婷  71   51   88   76   89
# 14  杜明延  70   80   63   53   89
# 15  唐雪豪  68   95   59   88   70
# 16  孫火清  66   77   68   74   62
# 17  陳逸凡  99   81   65   72   98
# 18  張雅芬  74   52   87   72   92
# 19  張伊映  83   95   96   87   80
# 20  陳倩潔  91  100   84   65   62
# 21  黃佩芬  78   74   50   90   92
# 22  林志成  86   62   77   69   65
# 23  簡美君  51   85   52   71   56
# 24  陳嘉淑  67   59   63   50   62
# 25  王士銘  60   80   70   81  100
# 26  吳柏誠  65   64   60   51   61
# 27  黃必琪  71   90   63   67   54
# 28  楊易政  63   57   56   76   88
# 29  林康亮  96   65   84  100   84
# 30  陳得映  84   62   72   68   63

# %%
students.index.name = '學號'
students.columns.name = '科目'
students
# Out:
# 科目   姓名  國文   英文   數學   歷史   生物
# 學號
# 1   龐皓芳  55   80   81   84   84
# 2   蔡欣汝  76   57   91   74   73
# 3   李政白  70   78   59   60   50
# 4   錢欣潔  67   72   95   98   80
# 5    戚亨  69   88   89   85   51
# 6   林希啟  67   54   60   67  100
# 7   盧冠發  59   62   51   85   74
# 8   許淑婷  68   84   99   52   61
# 9   張慧君  73   97  100   74   85
# 10  游倫城  72   70   57   56   68
# 11  李慈啟  70   55   78   57   91
# 12  王怡君  82   94   56   83   96
# 13  黃婷婷  71   51   88   76   89
# 14  杜明延  70   80   63   53   89
# 15  唐雪豪  68   95   59   88   70
# 16  孫火清  66   77   68   74   62
# 17  陳逸凡  99   81   65   72   98
# 18  張雅芬  74   52   87   72   92
# 19  張伊映  83   95   96   87   80
# 20  陳倩潔  91  100   84   65   62
# 21  黃佩芬  78   74   50   90   92
# 22  林志成  86   62   77   69   65
# 23  簡美君  51   85   52   71   56
# 24  陳嘉淑  67   59   63   50   62
# 25  王士銘  60   80   70   81  100
# 26  吳柏誠  65   64   60   51   61
# 27  黃必琪  71   90   63   67   54
# 28  楊易政  63   57   56   76   88
# 29  林康亮  96   65   84  100   84
# 30  陳得映  84   62   72   68   63

# %%
students.head(n=8)
# Out:
# 科目   姓名  國文  英文  數學  歷史   生物
# 學號
# 1   龐皓芳  55  80  81  84   84
# 2   蔡欣汝  76  57  91  74   73
# 3   李政白  70  78  59  60   50
# 4   錢欣潔  67  72  95  98   80
# 5    戚亨  69  88  89  85   51
# 6   林希啟  67  54  60  67  100
# 7   盧冠發  59  62  51  85   74
# 8   許淑婷  68  84  99  52   61

# %%
sum_series=students['國文']+students['英文']+students['數學']+students['國文']
sum_series
# Out:
# 學號
# 1     271
# 2     300
# 3     277
# 4     301
# 5     315
# 6     248
# 7     231
# 8     319
# 9     343
# 10    271
# 11    273
# 12    314
# 13    281
# 14    283
# 15    290
# 16    277
# 17    344
# 18    287
# 19    357
# 20    366
# 21    280
# 22    311
# 23    239
# 24    256
# 25    270
# 26    254
# 27    295
# 28    239
# 29    341
# 30    302
# dtype: int64

# %%
students['總分']=sum_series
students['平均']=sum_series/5.0
students
# Out:
# 科目   姓名  國文   英文   數學   歷史   生物   總分    平均
# 學號
# 1   龐皓芳  55   80   81   84   84  271  54.2
# 2   蔡欣汝  76   57   91   74   73  300  60.0
# 3   李政白  70   78   59   60   50  277  55.4
# 4   錢欣潔  67   72   95   98   80  301  60.2
# 5    戚亨  69   88   89   85   51  315  63.0
# 6   林希啟  67   54   60   67  100  248  49.6
# 7   盧冠發  59   62   51   85   74  231  46.2
# 8   許淑婷  68   84   99   52   61  319  63.8
# 9   張慧君  73   97  100   74   85  343  68.6
# 10  游倫城  72   70   57   56   68  271  54.2
# 11  李慈啟  70   55   78   57   91  273  54.6
# 12  王怡君  82   94   56   83   96  314  62.8
# 13  黃婷婷  71   51   88   76   89  281  56.2
# 14  杜明延  70   80   63   53   89  283  56.6
# 15  唐雪豪  68   95   59   88   70  290  58.0
# 16  孫火清  66   77   68   74   62  277  55.4
# 17  陳逸凡  99   81   65   72   98  344  68.8
# 18  張雅芬  74   52   87   72   92  287  57.4
# 19  張伊映  83   95   96   87   80  357  71.4
# 20  陳倩潔  91  100   84   65   62  366  73.2
# 21  黃佩芬  78   74   50   90   92  280  56.0
# 22  林志成  86   62   77   69   65  311  62.2
# 23  簡美君  51   85   52   71   56  239  47.8
# 24  陳嘉淑  67   59   63   50   62  256  51.2
# 25  王士銘  60   80   70   81  100  270  54.0
# 26  吳柏誠  65   64   60   51   61  254  50.8
# 27  黃必琪  71   90   63   67   54  295  59.0
# 28  楊易政  63   57   56   76   88  239  47.8
# 29  林康亮  96   65   84  100   84  341  68.2
# 30  陳得映  84   62   72   68   63  302  60.4
