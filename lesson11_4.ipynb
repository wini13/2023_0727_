# %%
import csv
with open('123.csv',encoding='utf-8',newline='') as file:
    csv_reader=csv.reader(file)
    next(csv_reader)
    csv_list=list(csv_reader)

display(csv_list)
# Out:
# [['楊健麟', '63', '62', '93', '71', '79'],
#  ['張伊映', '73', '64', '69', '60', '77'],
#  ['劉嘉泰', '57', '73', '93', '89', '63'],
#  ['羅佩樺', '84', '53', '90', '68', '100'],
#  ['游一鈺', '60', '95', '56', '71', '70'],
#  ['賴心怡', '64', '100', '80', '57', '70'],
#  ['楊偉翔', '64', '69', '70', '52', '76'],
#  ['簡佳樺', '51', '72', '63', '63', '74'],
#  ['張明惟', '92', '62', '88', '73', '63'],
#  ['洪奎夫', '96', '70', '57', '74', '52'],
#  ['游一鈺', '77', '93', '73', '98', '80'],
#  ['陳志偉', '88', '51', '97', '68', '64'],
#  ['林麗萍', '69', '69', '74', '70', '91'],
#  ['游治旺', '100', '69', '98', '80', '71'],
#  ['林詠斌', '99', '91', '68', '74', '91'],
#  ['黃佩玲', '74', '64', '79', '85', '60'],
#  ['方雅慧', '86', '68', '94', '87', '81'],
#  ['李進慧', '51', '77', '72', '96', '57'],
#  ['李佳彥', '84', '54', '58', '70', '98'],
#  ['張家秀', '69', '89', '65', '60', '64'],
#  ['黃靜怡', '69', '82', '74', '74', '96'],
#  ['馮淑芬', '77', '84', '74', '56', '53'],
#  ['李慶亮', '88', '100', '97', '73', '73'],
# ...

# %%
for student in csv_list:
    if student[0]=="鄭琇亞":
        print(student)
        break
# Out:
# ['鄭琇亞', '85', '60', '56', '99', '59']
